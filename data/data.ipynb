# %%
import numpy as np
from data_generator import burgers_1d_fd

# %%
# parameters
L = 2*np.pi               # domain length (0..2pi)
nx = 256
x = np.linspace(0, L, nx, endpoint=False)
# initial condition e.g. a single sine wave
u0 = -np.sin(x)           
nu = 0.01                 # viscosity
t_final = 2.0
dt = 0.0005               # small for stability/accuracy (reduce if unstable)

x, t_grid, U = burgers_1d_fd(u0, x, t_final, nu, dt)
# U shape: (nt, nx)  where nt = t_grid.size
